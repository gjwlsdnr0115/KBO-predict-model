# %%
import pandas as pd
from bayes_opt import BayesianOptimization
from sklearn.model_selection import train_test_split, GridSearchCV
from sklearn.ensemble import RandomForestClassifier, VotingClassifier
import xgboost as xgb
import warnings

# %%
# Load Data
df = pd.read_csv('data/final_dataset.csv')

# %%
# Create target label - Win: 1, Lose: 0
temp = []
for i in range(len(df)):
    if df.loc[i,'r'] >  df.loc[i,'l']:
        temp.append(1)
    elif df.loc[i,'r'] <  df.loc[i,'l']:
        temp.append(0)
    else :
        temp.append('draw')
df['win'] = temp        

# drop overlapping games
for i in range(int(len(df)/2)):
    df.drop(2*i+1, inplace=True)

# drop games with 'draw'    
df = df[df['win'] != 'draw']
df.set_index('game_key', inplace=True, drop=True)
df['win'] = pd.to_numeric(df['win'])
df
# Out:
#                    hp_1      hp_2      hp_3      h1_1      h1_2      h1_3  \
# game_key
# 20160413OBHH0  7.200000  2.000000  1.000000  0.250000  0.250000  0.250000
# 20160414HTSK0  2.571429  1.071429  1.500000  0.291667  0.392857  0.333333
# 20160414KTWO0  4.500000  1.500000  1.125000  0.234043  0.357143  0.297872
# 20160414LTLG0  2.250000  1.000000  2.500000  0.270270  0.391304  0.324324
# 20160414NCSS0  4.500000  1.416667  2.200000  0.388889  0.521739  0.722222
# ...                 ...       ...       ...       ...       ...       ...
# 20200719HHLG0  4.628571  1.400000  2.789474  0.247619  0.400000  0.380952
# 20200719KTNC0  5.837838  1.508108  1.600000  0.310185  0.366255  0.439815
# 20200719LTSS0  3.476395  1.171674  2.941176  0.339535  0.439689  0.432558
# 20200719OBHT0  5.108108  1.378378  1.818182  0.350000  0.422222  0.425000
# 20200719WOSK0  3.250000  1.152778  3.421053  0.284884  0.340426  0.343023
#
#                    h2_1      h2_2      h2_3      h3_1  ...      a8_1  \
# game_key                                               ...
# 20160413OBHH0  0.325581  0.355556  0.441860  0.257143  ...  1.000000
# 20160414HTSK0  0.218750  0.315789  0.281250  0.250000  ...  0.160000
# 20160414KTWO0  0.200000  0.200000  0.200000  0.346154  ...  0.142857
# 20160414LTLG0  0.500000  0.500000  0.833333  0.272727  ...  0.379310
# 20160414NCSS0  0.230769  0.302326  0.307692  0.315789  ...  0.200000
# ...                 ...       ...       ...       ...  ...       ...
# 20200719HHLG0  0.269767  0.327731  0.441860  0.285714  ...  0.209302
# 20200719KTNC0  0.295918  0.348837  0.352041  0.306383  ...  0.409091
# 20200719LTSS0  0.252632  0.284314  0.294737  0.345912  ...  0.151899
# 20200719OBHT0  0.309322  0.398524  0.593220  0.319048  ...  0.163636
# 20200719WOSK0  0.290909  0.365854  0.400000  0.285000  ...  0.277228
#
#                    a8_2      a8_3      a9_1      a9_2      a9_3     hit_r  r  \
# game_key
# 20160413OBHH0  1.000000  4.000000  0.275862  0.400000  0.310345  0.375000  3
# 20160414HTSK0  0.222222  0.400000  0.192308  0.300000  0.192308  0.378378  7
# 20160414KTWO0  0.250000  0.142857  0.216216  0.230769  0.378378  0.233333  4
# 20160414LTLG0  0.424242  0.413793  0.235294  0.315789  0.235294  0.228571  0
# 20160414NCSS0  0.230769  0.240000  0.166667  0.250000  0.277778  0.333333  7
# ...                 ...       ...       ...       ...       ...       ... ..
# 20200719HHLG0  0.306122  0.348837  0.260870  0.368852  0.347826  0.218750  6
# 20200719KTNC0  0.458333  0.409091  0.272727  0.360000  0.340909  0.333333  8
# 20200719LTSS0  0.200000  0.151899  0.266667  0.388889  0.266667  0.225806  1
# 20200719OBHT0  0.175439  0.236364  0.261084  0.313636  0.359606  0.250000  4
# 20200719WOSK0  0.352174  0.440594  0.202797  0.362637  0.237762  0.200000  4
#
#                l  win
# game_key
# 20160413OBHH0  7    0
# 20160414HTSK0  6    1
# 20160414KTWO0  5    0
# 20160414LTLG0  9    0
# 20160414NCSS0  5    1
# ...           ..  ...
# 20200719HHLG0  2    1
# 20200719KTNC0  2    1
# 20200719LTSS0  2    0
# 20200719OBHT0  8    0
# 20200719WOSK0  3    1
#
# [2918 rows x 64 columns]

# %%
# Create train, test dataset

X = df.iloc[:, :60].values
y = df.iloc[:, 63].values
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.30, random_state=23, stratify=y)


dtrain = xgb.DMatrix(X_train, label=y_train)
dtest = xgb.DMatrix(X_test, label=y_test)

# %%
# Define cross-validation variables used for parameter search

def XGB_CV(max_depth,
           gamma,
           min_child_weight,
           max_delta_step,
           subsample,
           colsample_bytree,
           eta,
         ):

    global AUCbest
    global ITERbest

    paramt = {
              'booster' : 'gbtree',
              'max_depth' : int(max_depth),
              'gamma' : gamma,
              'eta' : eta,
              'objective' : 'binary:logistic',
              'nthread' : 4,
              #'silent' : True,
              'eval_metric': 'auc',
              'subsample' : max(min(subsample, 1), 0),
              'colsample_bytree' : max(min(colsample_bytree, 1), 0),
              'min_child_weight' : min_child_weight,
              'max_delta_step' : int(max_delta_step),
              'seed' : 1001
      
              }
    folds = 10
    cv_score = 0
    print("\n Search parameters (%d-fold validation):\n %s" % (folds, paramt), file=log_file )
    log_file.flush()

    xgbc = xgb.cv(
                    paramt,
                    dtrain,
                    num_boost_round = 20000,
                    stratified = True,
                    nfold = folds,
                    early_stopping_rounds = 100,
                    metrics = 'auc',
                    show_stdv = True
                    
               )
    
    val_score = xgbc['test-auc-mean'].iloc[-1]
    train_score = xgbc['train-auc-mean'].iloc[-1]
    print(' Stopped after %d iterations with train-auc = %f val-auc = %f ( diff = %f ) train-gini = %f val-gini = %f' % ( len(xgbc), train_score, val_score, (train_score - val_score), (train_score*2-1),
(val_score*2-1)) )
    if ( val_score > AUCbest ):
        AUCbest = val_score
        ITERbest = len(xgbc)

    return (val_score*2) - 1

# %%
# Define the log file. If you repeat this run, new output will be added to it
log_file = open('model/Porto-AUC-5fold-XGB-run-01-v1-full.log', 'a')
AUCbest = -1.
ITERbest = 0

# %%
XGB_BO = BayesianOptimization(XGB_CV, {
                                    'max_depth': (2, 12),
                                    'gamma': (0.001, 10.0),
                                    'min_child_weight': (0, 20),
                                    'max_delta_step': (0, 10),
                                    'subsample': (0.4, 1.0),
                                    'colsample_bytree' :(0.4, 1.0),
                                    'eta' : (0.01, 0.3)
                                    })

# %%
with warnings.catch_warnings():
    warnings.filterwarnings('ignore')
    XGB_BO.maximize(init_points=2, n_iter=30, acq='ei', xi=0.0)
# Out:
# |   iter    |  target   | colsam... |    eta    |   gamma   | max_de... | max_depth | min_ch... | subsample |
# -------------------------------------------------------------------------------------------------------------
#  Stopped after 1 iterations with train-auc = 0.720302 val-auc = 0.524264 ( diff = 0.196038 ) train-gini = 0.440604 val-gini = 0.048528
# |  1        |  0.04853  |  0.4629   |  0.1167   |  5.215    |  0.1682   |  11.24    |  6.034    |  0.8964   |
#  Stopped after 22 iterations with train-auc = 0.725406 val-auc = 0.524258 ( diff = 0.201148 ) train-gini = 0.450812 val-gini = 0.048516
# |  2        |  0.04852  |  0.7892   |  0.2228   |  9.809    |  6.388    |  4.879    |  19.26    |  0.6188   |
#  Stopped after 94 iterations with train-auc = 0.687756 val-auc = 0.521887 ( diff = 0.165869 ) train-gini = 0.375513 val-gini = 0.043775
# |  3        |  0.04377  |  0.8555   |  0.03115  |  9.988    |  2.801    |  2.624    |  13.95    |  0.5629   |
#  Stopped after 1 iterations with train-auc = 0.574523 val-auc = 0.522472 ( diff = 0.052051 ) train-gini = 0.149046 val-gini = 0.044944
# |  4        |  0.04494  |  0.9287   |  0.1772   |  9.703    |  6.202    |  4.637    |  19.62    |  0.6893   |
#  Stopped after 9 iterations with train-auc = 0.817793 val-auc = 0.515670 ( diff = 0.302123 ) train-gini = 0.635586 val-gini = 0.031339
# |  5        |  0.03134  |  0.7264   |  0.2649   |  2.168    |  8.634    |  8.983    |  15.23    |  0.7015   |
#  Stopped after 2 iterations with train-auc = 0.603359 val-auc = 0.527625 ( diff = 0.075734 ) train-gini = 0.206718 val-gini = 0.055250
# |  6        |  0.05525  |  0.9812   |  0.2018   |  9.995    |  5.87     |  5.195    |  18.08    |  0.5463   |
#  Stopped after 53 iterations with train-auc = 0.733009 val-auc = 0.533289 ( diff = 0.199720 ) train-gini = 0.466018 val-gini = 0.066578
# |  7        |  0.06658  |  0.6377   |  0.2983   |  10.0     |  6.426    |  5.666    |  17.61    |  0.4202   |
#  Stopped after 21 iterations with train-auc = 0.699255 val-auc = 0.524875 ( diff = 0.174379 ) train-gini = 0.398509 val-gini = 0.049750
# |  8        |  0.04975  |  0.7831   |  0.175    |  9.601    |  7.106    |  6.876    |  17.94    |  0.4595   |
#  Stopped after 3 iterations with train-auc = 0.659916 val-auc = 0.549272 ( diff = 0.110645 ) train-gini = 0.319833 val-gini = 0.098544
# |  9        |  0.09854  |  0.48     |  0.0429   |  9.24     |  6.495    |  5.678    |  17.27    |  0.9704   |
#  Stopped after 7 iterations with train-auc = 0.714985 val-auc = 0.535126 ( diff = 0.179860 ) train-gini = 0.429971 val-gini = 0.070251
# |  10       |  0.07025  |  0.7139   |  0.01578  |  8.801    |  6.356    |  5.908    |  16.99    |  0.9175   |
#  Stopped after 3 iterations with train-auc = 0.667838 val-auc = 0.523006 ( diff = 0.144832 ) train-gini = 0.335676 val-gini = 0.046013
# |  11       |  0.04601  |  0.6674   |  0.1884   |  8.672    |  5.774    |  5.056    |  18.13    |  0.7849   |
#  Stopped after 3 iterations with train-auc = 0.728447 val-auc = 0.519665 ( diff = 0.208782 ) train-gini = 0.456894 val-gini = 0.039330
# |  12       |  0.03933  |  0.8448   |  0.2783   |  2.97     |  0.4091   |  9.394    |  10.54    |  0.623    |
#  Stopped after 2 iterations with train-auc = 0.660101 val-auc = 0.535767 ( diff = 0.124334 ) train-gini = 0.320201 val-gini = 0.071534
# |  13       |  0.07153  |  0.7888   |  0.2002   |  9.11     |  5.939    |  5.938    |  17.26    |  0.8697   |
#  Stopped after 163 iterations with train-auc = 0.880607 val-auc = 0.539088 ( diff = 0.341519 ) train-gini = 0.761214 val-gini = 0.078176
# |  14       |  0.07818  |  0.8069   |  0.1548   |  9.34     |  6.782    |  5.397    |  16.46    |  0.6998   |
#  Stopped after 30 iterations with train-auc = 0.755624 val-auc = 0.534359 ( diff = 0.221265 ) train-gini = 0.511249 val-gini = 0.068718
# |  15       |  0.06872  |  0.648    |  0.0654   |  8.743    |  7.493    |  5.454    |  17.6     |  0.6589   |
#  Stopped after 66 iterations with train-auc = 0.780163 val-auc = 0.526964 ( diff = 0.253199 ) train-gini = 0.560326 val-gini = 0.053928
# |  16       |  0.05393  |  0.5887   |  0.02499  |  9.673    |  6.441    |  6.558    |  16.92    |  0.8083   |
#  Stopped after 1 iterations with train-auc = 0.578804 val-auc = 0.526776 ( diff = 0.052028 ) train-gini = 0.157608 val-gini = 0.053552
# |  17       |  0.05355  |  0.5032   |  0.08107  |  9.261    |  6.308    |  4.375    |  16.55    |  0.6239   |
#  Stopped after 4 iterations with train-auc = 0.609126 val-auc = 0.524371 ( diff = 0.084755 ) train-gini = 0.218253 val-gini = 0.048742
# |  18       |  0.04874  |  0.4355   |  0.2452   |  8.991    |  7.607    |  5.897    |  16.93    |  0.4212   |
#  Stopped after 7 iterations with train-auc = 0.698103 val-auc = 0.540464 ( diff = 0.157639 ) train-gini = 0.396207 val-gini = 0.080928
# |  19       |  0.08093  |  0.416    |  0.0998   |  9.05     |  6.49     |  6.055    |  17.66    |  0.8915   |
#  Stopped after 54 iterations with train-auc = 0.810598 val-auc = 0.522596 ( diff = 0.288002 ) train-gini = 0.621197 val-gini = 0.045193
# |  20       |  0.04519  |  0.5861   |  0.1471   |  9.632    |  6.599    |  5.592    |  17.34    |  0.7941   |
#  Stopped after 2 iterations with train-auc = 0.673732 val-auc = 0.516991 ( diff = 0.156740 ) train-gini = 0.347463 val-gini = 0.033983
# |  21       |  0.03398  |  0.836    |  0.1534   |  2.567    |  9.196    |  4.866    |  1.571    |  0.6961   |
#  Stopped after 3 iterations with train-auc = 0.680243 val-auc = 0.539639 ( diff = 0.140604 ) train-gini = 0.360486 val-gini = 0.079278
# |  22       |  0.07928  |  0.5596   |  0.2545   |  8.342    |  6.814    |  5.827    |  17.29    |  0.8992   |
#  Stopped after 1 iterations with train-auc = 0.635385 val-auc = 0.544372 ( diff = 0.091013 ) train-gini = 0.270769 val-gini = 0.088743
# |  23       |  0.08874  |  0.7522   |  0.1292   |  8.618    |  6.311    |  5.525    |  16.77    |  0.9867   |
#  Stopped after 21 iterations with train-auc = 0.812097 val-auc = 0.530126 ( diff = 0.281971 ) train-gini = 0.624195 val-gini = 0.060252
# |  24       |  0.06025  |  0.96     |  0.2446   |  6.955    |  9.931    |  5.582    |  16.01    |  0.5894   |
#  Stopped after 2 iterations with train-auc = 0.763460 val-auc = 0.541100 ( diff = 0.222359 ) train-gini = 0.526920 val-gini = 0.082201
# |  25       |  0.0822   |  0.5509   |  0.1186   |  6.832    |  4.412    |  8.388    |  7.447    |  0.9483   |
#  Stopped after 5 iterations with train-auc = 0.776899 val-auc = 0.512855 ( diff = 0.264044 ) train-gini = 0.553798 val-gini = 0.025711
# |  26       |  0.02571  |  0.7983   |  0.1057   |  9.596    |  3.493    |  11.79    |  1.823    |  0.6651   |
#  Stopped after 5 iterations with train-auc = 0.780684 val-auc = 0.534590 ( diff = 0.246095 ) train-gini = 0.561368 val-gini = 0.069179
# |  27       |  0.06918  |  0.5651   |  0.1202   |  0.8501   |  2.093    |  8.401    |  19.14    |  0.9481   |
#  Stopped after 2 iterations with train-auc = 0.598909 val-auc = 0.535548 ( diff = 0.063361 ) train-gini = 0.197817 val-gini = 0.071095
# |  28       |  0.0711   |  0.4348   |  0.2816   |  7.821    |  6.476    |  3.177    |  5.267    |  0.5468   |
#  Stopped after 6 iterations with train-auc = 0.676370 val-auc = 0.528674 ( diff = 0.147696 ) train-gini = 0.352740 val-gini = 0.057348
# |  29       |  0.05735  |  0.7077   |  0.1858   |  9.846    |  1.567    |  8.514    |  15.51    |  0.6364   |
#  Stopped after 3 iterations with train-auc = 0.816989 val-auc = 0.533610 ( diff = 0.283379 ) train-gini = 0.633977 val-gini = 0.067220
# |  30       |  0.06722  |  0.6439   |  0.2081   |  5.386    |  1.641    |  9.873    |  0.2317   |  0.6495   |
#  Stopped after 1 iterations with train-auc = 0.608126 val-auc = 0.517212 ( diff = 0.090914 ) train-gini = 0.216252 val-gini = 0.034424
# |  31       |  0.03442  |  0.5744   |  0.1732   |  9.047    |  6.869    |  6.072    |  17.29    |  0.8075   |
#  Stopped after 1 iterations with train-auc = 0.780448 val-auc = 0.529707 ( diff = 0.250741 ) train-gini = 0.560896 val-gini = 0.059415
# |  32       |  0.05941  |  0.8264   |  0.2877   |  4.636    |  9.81     |  7.692    |  1.459    |  0.967    |
# =============================================================================================================

# %%
XGB_BO2 = BayesianOptimization(XGB_CV, {
                                    'max_depth': (2, 12),
                                    'gamma': (0.001, 10.0),
                                    'min_child_weight': (0, 20),
                                    'max_delta_step': (0, 10),
                                    'subsample': (0.4, 1.0),
                                    'colsample_bytree' :(0.4, 1.0),
                                    'eta' : (0.01, 0.1)
                                    })
with warnings.catch_warnings():
    warnings.filterwarnings('ignore')
    XGB_BO2.maximize(init_points=2, n_iter=30, acq='ei', xi=0.0)
# Out:
# |   iter    |  target   | colsam... |    eta    |   gamma   | max_de... | max_depth | min_ch... | subsample |
# -------------------------------------------------------------------------------------------------------------
#  Stopped after 5 iterations with train-auc = 0.831337 val-auc = 0.520853 ( diff = 0.310484 ) train-gini = 0.662674 val-gini = 0.041705
# |  1        |  0.04171  |  0.4529   |  0.083    |  2.182    |  5.787    |  9.67     |  7.653    |  0.7494   |
#  Stopped after 5 iterations with train-auc = 0.654452 val-auc = 0.535725 ( diff = 0.118727 ) train-gini = 0.308904 val-gini = 0.071449
# |  2        |  0.07145  |  0.7682   |  0.05808  |  3.928    |  3.211    |  6.849    |  18.34    |  0.4474   |
#  Stopped after 27 iterations with train-auc = 0.807479 val-auc = 0.521219 ( diff = 0.286260 ) train-gini = 0.614958 val-gini = 0.042439
# |  3        |  0.04244  |  0.5732   |  0.01708  |  4.074    |  2.705    |  6.957    |  17.61    |  0.716    |
#  Stopped after 8 iterations with train-auc = 0.796119 val-auc = 0.524938 ( diff = 0.271181 ) train-gini = 0.592238 val-gini = 0.049876
# |  4        |  0.04988  |  0.6456   |  0.02586  |  0.4975   |  2.255    |  7.513    |  5.389    |  0.4591   |
#  Stopped after 1 iterations with train-auc = 0.635881 val-auc = 0.541390 ( diff = 0.094492 ) train-gini = 0.271763 val-gini = 0.082779
# |  5        |  0.08278  |  0.6172   |  0.03112  |  8.142    |  4.475    |  6.16     |  19.94    |  0.9544   |
#  Stopped after 4 iterations with train-auc = 0.671111 val-auc = 0.529114 ( diff = 0.141996 ) train-gini = 0.342221 val-gini = 0.058229
# |  6        |  0.05823  |  0.7152   |  0.05072  |  9.563    |  1.243    |  6.684    |  17.85    |  0.8102   |
#  Stopped after 7 iterations with train-auc = 0.721801 val-auc = 0.524764 ( diff = 0.197038 ) train-gini = 0.443603 val-gini = 0.049527
# |  7        |  0.04953  |  0.4262   |  0.06557  |  5.638    |  6.041    |  4.135    |  13.54    |  0.7806   |
#  Stopped after 37 iterations with train-auc = 0.999977 val-auc = 0.515593 ( diff = 0.484384 ) train-gini = 0.999953 val-gini = 0.031185
# |  8        |  0.03119  |  0.8449   |  0.03385  |  1.405    |  2.372    |  11.76    |  1.67     |  0.778    |
#  Stopped after 17 iterations with train-auc = 0.706403 val-auc = 0.550088 ( diff = 0.156315 ) train-gini = 0.412806 val-gini = 0.100175
# |  9        |  0.1002   |  0.5062   |  0.04301  |  7.285    |  3.139    |  7.281    |  15.78    |  0.4721   |
#  Stopped after 24 iterations with train-auc = 0.713173 val-auc = 0.533845 ( diff = 0.179328 ) train-gini = 0.426345 val-gini = 0.067689
# |  10       |  0.06769  |  0.8454   |  0.07042  |  5.039    |  1.505    |  3.949    |  13.91    |  0.4095   |
#  Stopped after 2 iterations with train-auc = 0.680162 val-auc = 0.528755 ( diff = 0.151407 ) train-gini = 0.360323 val-gini = 0.057509
# |  11       |  0.05751  |  0.7067   |  0.08426  |  6.048    |  9.699    |  5.364    |  14.42    |  0.8297   |
#  Stopped after 6 iterations with train-auc = 0.628746 val-auc = 0.524142 ( diff = 0.104604 ) train-gini = 0.257492 val-gini = 0.048285
# |  12       |  0.04828  |  0.6586   |  0.05898  |  7.921    |  7.04     |  2.252    |  17.82    |  0.8158   |
#  Stopped after 6 iterations with train-auc = 0.837386 val-auc = 0.530322 ( diff = 0.307065 ) train-gini = 0.674773 val-gini = 0.060644
# |  13       |  0.06064  |  0.8067   |  0.08236  |  5.552    |  1.317    |  6.42     |  4.692    |  0.8398   |
#  Stopped after 1 iterations with train-auc = 0.646981 val-auc = 0.542592 ( diff = 0.104389 ) train-gini = 0.293961 val-gini = 0.085183
# |  14       |  0.08518  |  0.6843   |  0.01754  |  4.291    |  8.738    |  5.053    |  14.95    |  0.8725   |
#  Stopped after 6 iterations with train-auc = 0.723358 val-auc = 0.530874 ( diff = 0.192484 ) train-gini = 0.446716 val-gini = 0.061748
# |  15       |  0.06175  |  0.5145   |  0.09387  |  8.052    |  9.923    |  4.449    |  7.356    |  0.9248   |
#  Stopped after 1 iterations with train-auc = 0.592713 val-auc = 0.533669 ( diff = 0.059045 ) train-gini = 0.185427 val-gini = 0.067337
# |  16       |  0.06734  |  0.9004   |  0.01228  |  9.726    |  0.3807   |  3.211    |  16.0     |  0.8841   |
#  Stopped after 20 iterations with train-auc = 0.743216 val-auc = 0.529068 ( diff = 0.214149 ) train-gini = 0.486432 val-gini = 0.058135
# |  17       |  0.05814  |  0.8673   |  0.03751  |  1.328    |  0.01437  |  9.121    |  19.32    |  0.5081   |
#  Stopped after 5 iterations with train-auc = 0.969718 val-auc = 0.540896 ( diff = 0.428822 ) train-gini = 0.939437 val-gini = 0.081792
# |  18       |  0.08179  |  0.933    |  0.02282  |  0.2719   |  2.463    |  9.278    |  2.43     |  0.9489   |
#  Stopped after 8 iterations with train-auc = 0.813557 val-auc = 0.536945 ( diff = 0.276612 ) train-gini = 0.627113 val-gini = 0.073889
# |  19       |  0.07389  |  0.7204   |  0.06267  |  0.8207   |  3.973    |  8.519    |  14.78    |  0.835    |
#  Stopped after 8 iterations with train-auc = 0.805968 val-auc = 0.533671 ( diff = 0.272297 ) train-gini = 0.611935 val-gini = 0.067341
# |  20       |  0.06734  |  0.4194   |  0.07507  |  2.367    |  5.305    |  9.704    |  4.934    |  0.4468   |
#  Stopped after 3 iterations with train-auc = 0.754014 val-auc = 0.543967 ( diff = 0.210047 ) train-gini = 0.508028 val-gini = 0.087933
# |  21       |  0.08793  |  0.9898   |  0.03354  |  5.668    |  6.294    |  10.76    |  13.67    |  0.976    |
#  Stopped after 3 iterations with train-auc = 0.602863 val-auc = 0.520712 ( diff = 0.082151 ) train-gini = 0.205726 val-gini = 0.041425
# |  22       |  0.04142  |  0.6003   |  0.0657   |  8.927    |  1.117    |  3.432    |  9.622    |  0.5604   |
#  Stopped after 18 iterations with train-auc = 0.886309 val-auc = 0.538400 ( diff = 0.347909 ) train-gini = 0.772618 val-gini = 0.076800
# |  23       |  0.0768   |  0.482    |  0.06747  |  3.406    |  1.264    |  6.583    |  9.51     |  0.7787   |
#  Stopped after 76 iterations with train-auc = 0.867346 val-auc = 0.528055 ( diff = 0.339292 ) train-gini = 0.734693 val-gini = 0.056109
# |  24       |  0.05611  |  0.5837   |  0.04159  |  7.639    |  1.533    |  9.718    |  14.37    |  0.6656   |
#  Stopped after 2 iterations with train-auc = 0.673616 val-auc = 0.541836 ( diff = 0.131780 ) train-gini = 0.347231 val-gini = 0.083672
# |  25       |  0.08367  |  0.4672   |  0.04456  |  9.317    |  4.507    |  10.62    |  0.9897   |  0.6105   |
#  Stopped after 39 iterations with train-auc = 0.719813 val-auc = 0.525728 ( diff = 0.194085 ) train-gini = 0.439625 val-gini = 0.051456
# |  26       |  0.05146  |  0.7504   |  0.02883  |  9.431    |  9.515    |  3.094    |  9.26     |  0.6954   |
#  Stopped after 1 iterations with train-auc = 0.714888 val-auc = 0.529102 ( diff = 0.185786 ) train-gini = 0.429776 val-gini = 0.058203
# |  27       |  0.0582   |  0.5843   |  0.05022  |  4.911    |  5.709    |  8.606    |  9.401    |  0.9743   |
#  Stopped after 5 iterations with train-auc = 0.992779 val-auc = 0.543524 ( diff = 0.449255 ) train-gini = 0.985559 val-gini = 0.087048
# |  28       |  0.08705  |  0.8998   |  0.04258  |  2.428    |  3.303    |  10.63    |  0.9692   |  0.959    |
#  Stopped after 129 iterations with train-auc = 0.742555 val-auc = 0.524181 ( diff = 0.218374 ) train-gini = 0.485109 val-gini = 0.048361
# |  29       |  0.04836  |  0.6362   |  0.03127  |  2.481    |  8.673    |  2.202    |  10.77    |  0.5093   |
#  Stopped after 72 iterations with train-auc = 0.858991 val-auc = 0.522383 ( diff = 0.336608 ) train-gini = 0.717983 val-gini = 0.044767
# |  30       |  0.04477  |  0.553    |  0.08025  |  8.183    |  4.529    |  6.317    |  19.79    |  0.8303   |
#  Stopped after 2 iterations with train-auc = 0.692962 val-auc = 0.538404 ( diff = 0.154558 ) train-gini = 0.385925 val-gini = 0.076809
# |  31       |  0.07681  |  0.8694   |  0.09441  |  1.174    |  6.952    |  5.752    |  18.99    |  0.953    |
#  Stopped after 3 iterations with train-auc = 0.735899 val-auc = 0.544497 ( diff = 0.191402 ) train-gini = 0.471798 val-gini = 0.088995
# |  32       |  0.08899  |  0.8474   |  0.03173  |  7.063    |  4.015    |  8.972    |  14.43    |  0.9581   |
# =============================================================================================================

# %%
XGB_BO3 = BayesianOptimization(XGB_CV, {
                                    'max_depth': (2, 12),
                                    'gamma': (0.001, 10.0),
                                    'min_child_weight': (0, 20),
                                    'max_delta_step': (0, 10),
                                    'subsample': (0.4, 1.0),
                                    'colsample_bytree' :(0.4, 1.0),
                                    'eta' : (0.01, 0.2)
                                    })
with warnings.catch_warnings():
    warnings.filterwarnings('ignore')
    XGB_BO3.maximize(init_points=2, n_iter=30, acq='ei', xi=0.0)
# Out:
# |   iter    |  target   | colsam... |    eta    |   gamma   | max_de... | max_depth | min_ch... | subsample |
# -------------------------------------------------------------------------------------------------------------
#  Stopped after 43 iterations with train-auc = 0.947553 val-auc = 0.532249 ( diff = 0.415303 ) train-gini = 0.895105 val-gini = 0.064499
# |  1        |  0.0645   |  0.8739   |  0.06731  |  3.206    |  9.938    |  6.469    |  10.39    |  0.7307   |
#  Stopped after 6 iterations with train-auc = 0.667532 val-auc = 0.526722 ( diff = 0.140810 ) train-gini = 0.335064 val-gini = 0.053443
# |  2        |  0.05344  |  0.4147   |  0.04601  |  1.99     |  6.783    |  10.8     |  14.5     |  0.4211   |
#  Stopped after 16 iterations with train-auc = 0.660197 val-auc = 0.528364 ( diff = 0.131834 ) train-gini = 0.320394 val-gini = 0.056727
# |  3        |  0.05673  |  0.6004   |  0.1609   |  6.179    |  2.368    |  2.993    |  15.24    |  0.4558   |
#  Stopped after 1 iterations with train-auc = 0.588377 val-auc = 0.533744 ( diff = 0.054633 ) train-gini = 0.176753 val-gini = 0.067488
# |  4        |  0.06749  |  0.7863   |  0.01172  |  8.602    |  3.448    |  3.108    |  11.94    |  0.7215   |
#  Stopped after 18 iterations with train-auc = 0.790081 val-auc = 0.520030 ( diff = 0.270051 ) train-gini = 0.580163 val-gini = 0.040060
# |  5        |  0.04006  |  0.6411   |  0.1587   |  7.115    |  5.483    |  11.21    |  10.56    |  0.4763   |
#  Stopped after 14 iterations with train-auc = 0.697281 val-auc = 0.536798 ( diff = 0.160482 ) train-gini = 0.394561 val-gini = 0.073596
# |  6        |  0.0736   |  0.732    |  0.04005  |  8.392    |  4.393    |  3.274    |  11.96    |  0.7475   |
#  Stopped after 141 iterations with train-auc = 0.821645 val-auc = 0.523891 ( diff = 0.297754 ) train-gini = 0.643291 val-gini = 0.047782
# |  7        |  0.04778  |  0.7009   |  0.05747  |  8.351    |  5.519    |  3.277    |  11.7     |  0.8081   |
#  Stopped after 2 iterations with train-auc = 0.634969 val-auc = 0.535279 ( diff = 0.099690 ) train-gini = 0.269938 val-gini = 0.070557
# |  8        |  0.07056  |  0.954    |  0.09236  |  8.897    |  4.119    |  3.227    |  11.43    |  0.9391   |
#  Stopped after 68 iterations with train-auc = 0.752671 val-auc = 0.528712 ( diff = 0.223959 ) train-gini = 0.505343 val-gini = 0.057424
# |  9        |  0.05742  |  0.5417   |  0.08651  |  9.585    |  4.191    |  3.619    |  11.92    |  0.7779   |
#  Stopped after 2 iterations with train-auc = 0.630713 val-auc = 0.537626 ( diff = 0.093087 ) train-gini = 0.261425 val-gini = 0.075252
# |  10       |  0.07525  |  0.8799   |  0.01167  |  8.627    |  3.743    |  3.186    |  10.91    |  0.9302   |
#  Stopped after 37 iterations with train-auc = 0.840523 val-auc = 0.529923 ( diff = 0.310599 ) train-gini = 0.681045 val-gini = 0.059847
# |  11       |  0.05985  |  0.8792   |  0.1225   |  8.002    |  4.248    |  4.178    |  11.79    |  0.8097   |
#  Stopped after 3 iterations with train-auc = 0.618779 val-auc = 0.528629 ( diff = 0.090150 ) train-gini = 0.237558 val-gini = 0.057258
# |  12       |  0.05726  |  0.9369   |  0.113    |  8.896    |  4.36     |  2.952    |  10.33    |  0.9756   |
#  Stopped after 6 iterations with train-auc = 0.689336 val-auc = 0.539228 ( diff = 0.150108 ) train-gini = 0.378672 val-gini = 0.078457
# |  13       |  0.07846  |  0.7915   |  0.1446   |  8.376    |  3.69     |  3.742    |  12.6     |  0.936    |
#  Stopped after 2 iterations with train-auc = 0.577547 val-auc = 0.527745 ( diff = 0.049803 ) train-gini = 0.155095 val-gini = 0.055489
# |  14       |  0.05549  |  0.9796   |  0.04181  |  3.431    |  1.98     |  2.861    |  15.86    |  0.4677   |
#  Stopped after 2 iterations with train-auc = 0.705648 val-auc = 0.537719 ( diff = 0.167929 ) train-gini = 0.411295 val-gini = 0.075438
# |  15       |  0.07544  |  0.8219   |  0.1512   |  6.426    |  0.8217   |  5.454    |  13.77    |  0.9671   |
#  Stopped after 7 iterations with train-auc = 0.690858 val-auc = 0.520782 ( diff = 0.170077 ) train-gini = 0.381717 val-gini = 0.041563
# |  16       |  0.04156  |  0.9487   |  0.08095  |  8.103    |  3.908    |  3.304    |  11.32    |  0.7836   |
#  Stopped after 6 iterations with train-auc = 0.891953 val-auc = 0.535932 ( diff = 0.356021 ) train-gini = 0.783907 val-gini = 0.071864
# |  17       |  0.07186  |  0.6984   |  0.09047  |  3.242    |  2.354    |  7.425    |  7.3      |  0.9682   |
#  Stopped after 2 iterations with train-auc = 0.675218 val-auc = 0.523891 ( diff = 0.151327 ) train-gini = 0.350435 val-gini = 0.047782
# |  18       |  0.04778  |  0.8268   |  0.1391   |  6.409    |  0.1827   |  8.379    |  19.67    |  0.8181   |
#  Stopped after 42 iterations with train-auc = 0.943853 val-auc = 0.530040 ( diff = 0.413814 ) train-gini = 0.887706 val-gini = 0.060079
# |  19       |  0.06008  |  0.5291   |  0.09222  |  3.941    |  7.223    |  8.824    |  15.04    |  0.7766   |
#  Stopped after 7 iterations with train-auc = 0.895275 val-auc = 0.531878 ( diff = 0.363397 ) train-gini = 0.790550 val-gini = 0.063755
# |  20       |  0.06376  |  0.9511   |  0.06124  |  5.371    |  0.6085   |  7.773    |  2.769    |  0.7751   |
#  Stopped after 6 iterations with train-auc = 0.720757 val-auc = 0.519909 ( diff = 0.200848 ) train-gini = 0.441514 val-gini = 0.039818
# |  21       |  0.03982  |  0.6623   |  0.09622  |  5.856    |  7.166    |  9.435    |  10.96    |  0.5094   |
#  Stopped after 19 iterations with train-auc = 0.946977 val-auc = 0.529793 ( diff = 0.417184 ) train-gini = 0.893954 val-gini = 0.059586
# |  22       |  0.05959  |  0.4904   |  0.1849   |  3.387    |  7.267    |  9.755    |  3.834    |  0.5145   |
#  Stopped after 52 iterations with train-auc = 0.836450 val-auc = 0.532349 ( diff = 0.304101 ) train-gini = 0.672900 val-gini = 0.064698
# |  23       |  0.0647   |  0.4449   |  0.09703  |  5.179    |  6.366    |  3.889    |  3.251    |  0.6082   |
#  Stopped after 1 iterations with train-auc = 0.606468 val-auc = 0.512296 ( diff = 0.094172 ) train-gini = 0.212936 val-gini = 0.024593
# |  24       |  0.02459  |  0.7463   |  0.04873  |  9.287    |  2.739    |  11.59    |  8.419    |  0.5596   |
#  Stopped after 33 iterations with train-auc = 0.717494 val-auc = 0.524588 ( diff = 0.192907 ) train-gini = 0.434989 val-gini = 0.049176
# |  25       |  0.04918  |  0.5865   |  0.05708  |  9.263    |  6.09     |  3.894    |  12.98    |  0.7423   |
#  Stopped after 29 iterations with train-auc = 0.721433 val-auc = 0.520497 ( diff = 0.200936 ) train-gini = 0.442866 val-gini = 0.040993
# |  26       |  0.04099  |  0.7497   |  0.09485  |  3.739    |  6.246    |  2.032    |  6.577    |  0.8529   |
#  Stopped after 7 iterations with train-auc = 0.689320 val-auc = 0.534068 ( diff = 0.155252 ) train-gini = 0.378640 val-gini = 0.068136
# |  27       |  0.06814  |  0.9327   |  0.09842  |  9.753    |  5.042    |  4.394    |  18.77    |  0.8495   |
#  Stopped after 3 iterations with train-auc = 0.785166 val-auc = 0.548488 ( diff = 0.236678 ) train-gini = 0.570331 val-gini = 0.096975
# |  28       |  0.09698  |  0.8562   |  0.01318  |  2.898    |  3.879    |  10.69    |  12.48    |  0.9745   |
#  Stopped after 39 iterations with train-auc = 0.754070 val-auc = 0.528238 ( diff = 0.225832 ) train-gini = 0.508141 val-gini = 0.056476
# |  29       |  0.05648  |  0.638    |  0.08606  |  6.65     |  5.142    |  9.379    |  18.43    |  0.4207   |
#  Stopped after 2 iterations with train-auc = 0.658593 val-auc = 0.518878 ( diff = 0.139715 ) train-gini = 0.317187 val-gini = 0.037756
# |  30       |  0.03776  |  0.5418   |  0.1782   |  0.7505   |  6.906    |  6.139    |  14.1     |  0.6101   |
#  Stopped after 38 iterations with train-auc = 0.814946 val-auc = 0.526899 ( diff = 0.288047 ) train-gini = 0.629892 val-gini = 0.053797
# |  31       |  0.0538   |  0.9562   |  0.08695  |  6.195    |  7.772    |  3.939    |  3.015    |  0.6223   |
#  Stopped after 1 iterations with train-auc = 0.568629 val-auc = 0.537546 ( diff = 0.031083 ) train-gini = 0.137258 val-gini = 0.075091
# |  32       |  0.07509  |  0.635    |  0.1795   |  9.641    |  9.72     |  4.5      |  19.57    |  0.5321   |
# =============================================================================================================

# %%
params = XGB_BO.max
params2 = XGB_BO2.max
params3 = XGB_BO3.max

# %%
# Train classifiers
XGB_clf1 = xgb.XGBClassifier(booster = 'gbtree',
                             max_depth = int(params['params']['max_depth']),
                             gamma = params['params']['gamma'],
                             eta = params['params']['eta'],
                             objective = 'binary:logistic',
                             eval_metric= 'auc',
                             subsample = max(min(params['params']['subsample'] , 1), 0),
                             colsample_bytree = max(min(params['params']['colsample_bytree'], 1), 0),\
                             min_child_weight = params['params']['min_child_weight'],
                             max_delta_step = int(params['params']['max_delta_step']),
                             n_estimators = 500
                            )

# %%
XGB_clf2 = xgb.XGBClassifier(booster = 'gbtree',
                             max_depth = int(params2['params']['max_depth']),
                             gamma = params2['params']['gamma'],
                             eta = params2['params']['eta'],
                             objective = 'binary:logistic',
                             eval_metric= 'auc',
                             subsample = max(min(params2['params']['subsample'] , 1), 0),
                             colsample_bytree = max(min(params2['params']['colsample_bytree'], 1), 0),\
                             min_child_weight = params2['params']['min_child_weight'],
                             max_delta_step = int(params2['params']['max_delta_step']),
                             n_estimators = 500
                            )

# %%
XGB_clf3 = xgb.XGBClassifier(booster = 'gbtree',
                             max_depth = int(params3['params']['max_depth']),
                             gamma = params3['params']['gamma'],
                             eta = params3['params']['eta'],
                             objective = 'binary:logistic',
                             eval_metric= 'auc',
                             subsample = max(min(params3['params']['subsample'] , 1), 0),
                             colsample_bytree = max(min(params3['params']['colsample_bytree'], 1), 0),\
                             min_child_weight = params3['params']['min_child_weight'],
                             max_delta_step = int(params3['params']['max_delta_step']),
                             n_estimators = 500
                            )

# %%
clf= RandomForestClassifier(n_estimators=300, criterion='entropy', min_samples_split=2,
  min_samples_leaf=1, max_features='auto', bootstrap=False, oob_score=False, n_jobs=-1, random_state=123,
  verbose=0)


param_grid = {'max_depth' : [8,12,14, 16],
              'min_samples_leaf' : [4, 6, 8, 12, 18],
              'min_samples_split' : [6, 8, 16],
             }

grid_search = GridSearchCV(clf, param_grid=param_grid, verbose=1,scoring='accuracy', n_jobs=-1)
grid_search.fit(X_train, y_train)

RF_BEST = grid_search.best_estimator_
'''
RandomForestClassifier(bootstrap=False, criterion='entropy', max_depth=14,
                       min_samples_leaf=8, min_samples_split=8,
                       n_estimators=300, n_jobs=4, random_state=123)
'''
# Out:
# Fitting 5 folds for each of 60 candidates, totalling 300 fits
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  34 tasks      | elapsed:   24.5s
# [Parallel(n_jobs=-1)]: Done 184 tasks      | elapsed:  2.2min
# [Parallel(n_jobs=-1)]: Done 300 out of 300 | elapsed:  3.6min finished
# "\nRandomForestClassifier(bootstrap=False, criterion='entropy', max_depth=14,\n                       min_samples_leaf=8, min_samples_split=8,\n                       n_estimators=300, n_jobs=4, random_state=123)\n"

# %%
voting_clf = VotingClassifier(
    estimators=[('xgb1', XGB_clf1),
                ('xgb2', XGB_clf2),
                ('xgb3', XGB_clf3), 
                ('rf', RF_BEST)],
    voting='soft', n_jobs=-1)

# %%
import pickle
# Save model

with open('./model/voting_model_win.pkl', 'wb') as f:
    pickle.dump(voting_clf, f)
    
# Load model
with open('./model/voting_model_win.pkl', 'rb') as f:
    voting_clf = pickle.load(f)

# %%
# Test results
voting_clf.fit(X_train,y_train)
voting_clf.score(X_test, y_test)
# Out:
# 0.5787671232876712
